# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\pickle\metrics_c"
files = os.listdir(path)
cifar = []
for file in files:
  cifar.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df_r = pd.DataFrame(cifar, index = ['Lenet5', 'Resnet18', 'Alexnet','VGGnet'])
df_r.transpose()
# Out:
#                                 Lenet5  \
# 0   {'train_loss': 1.7293449603688076}
# 1     {'train_loss': 1.42746349399352}
# 2    {'train_loss': 1.307708763100607}
# 3   {'train_loss': 1.2267939901108023}
# 4   {'train_loss': 1.1673546091979727}
# ..                                 ...
# 95  {'train_loss': 0.8257034416393856}
# 96  {'train_loss': 0.8258802122472192}
# 97   {'train_loss': 0.825902609721474}
# 98  {'train_loss': 0.8256658734872823}
# 99  {'train_loss': 0.8257807653273463}
#
#                                   Resnet18  \
# 0       {'train_loss': 1.6409377707239916}
# 1       {'train_loss': 1.0901057837564316}
# 2       {'train_loss': 0.8160894726548353}
# 3        {'train_loss': 0.643138652414922}
# 4       {'train_loss': 0.5136742927991521}
# ..                                     ...
# 95   {'train_loss': 4.322407997108984e-05}
# 96   {'train_loss': 4.325689385897182e-05}
# 97  {'train_loss': 4.3218365411184145e-05}
# 98  {'train_loss': 4.3246575194392596e-05}
# ...

# %%
df_flattened = pd.concat([pd.json_normalize(df_r[col]) for col in df_r], axis=1)
fin = df_flattened.transpose()
print(fin)
# Out:
#                    0         1         2         3
# train_loss  1.729345  1.640938  1.748048  1.627393
# train_loss  1.427463  1.090106  1.284625  1.187558
# train_loss  1.307709  0.816089  1.085040  0.976593
# train_loss  1.226794  0.643139  0.952710  0.831111
# train_loss  1.167355  0.513674  0.849793  0.728390
# ...              ...       ...       ...       ...
# train_loss  0.825703  0.000043  0.182601  0.064267
# train_loss  0.825880  0.000043  0.183176  0.062724
# train_loss  0.825903  0.000043  0.183891  0.062776
# train_loss  0.825666  0.000043  0.179875  0.061185
# train_loss  0.825781  0.000043  0.180771  0.061503
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
epochs = list(range(1,101))
plt.figure()
plt.title('Training Loss Curve')
plt.plot(epochs,fin[0], label='Lenet5')
plt.plot(epochs,fin[1], label='Resnet18')
plt.plot(epochs,fin[2], label='Alexnet')
plt.plot(epochs,fin[3], label='VGGnet')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\mnis\metrics_m"
files = os.listdir(path)
mnist = []
for file in files:
  mnist.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df_m = pd.DataFrame(mnist, index = ['Lenet5', 'Resnet18', 'Alexnet','VGGnet'])
df_m.transpose()
# Out:
#                                     Lenet5  \
# 0      {'train_loss': 0.19753620239365846}
# 1      {'train_loss': 0.06757054773547376}
# 2     {'train_loss': 0.049001102165179326}
# 3      {'train_loss': 0.04017191040496497}
# 4      {'train_loss': 0.03117188742418657}
# 5      {'train_loss': 0.02845804115701467}
# 6     {'train_loss': 0.022605522926900448}
# 7      {'train_loss': 0.01983981628325831}
# 8     {'train_loss': 0.018748972786919452}
# 9     {'train_loss': 0.016438375960335816}
# 10    {'train_loss': 0.005878524054828934}
# 11   {'train_loss': 0.0029772825398169515}
# 12   {'train_loss': 0.0019672965297594905}
# 13   {'train_loss': 0.0015147646401148223}
# 14   {'train_loss': 0.0010923821175143204}
# 15   {'train_loss': 0.0008507415171879096}
# 16   {'train_loss': 0.0005835386361056669}
# 17     {'train_loss': 0.00037775522875923}
# 18  {'train_loss': 0.00027451136292756855}
# 19   {'train_loss': 0.0003558772674327418}
#
#                                   Resnet18  \
# ...

# %%
df_flattened = pd.concat([pd.json_normalize(df_m[col]) for col in df_m], axis=1)
fin = df_flattened.transpose()
print(fin)
# Out:
#                    0         1         2         3
# train_loss  0.197536  0.111346  0.262063  0.172713
# train_loss  0.067571  0.052723  0.096285  0.064005
# train_loss  0.049001  0.038261  0.077469  0.047246
# train_loss  0.040172  0.032946  0.067040  0.041071
# train_loss  0.031172  0.025474  0.058193  0.036537
# train_loss  0.028458  0.021565  0.050235  0.033428
# train_loss  0.022606  0.016862  0.051258  0.031806
# train_loss  0.019840  0.013954  0.044779  0.027943
# train_loss  0.018749  0.012092  0.050988  0.029120
# train_loss  0.016438  0.010054  0.046179  0.027018
# train_loss  0.005879  0.003263  0.018472  0.008287
# train_loss  0.002977  0.001640  0.010517  0.002785
# train_loss  0.001967  0.001037  0.006646  0.001192
# train_loss  0.001515  0.000881  0.005020  0.000512
# train_loss  0.001092  0.000489  0.004294  0.000222
# train_loss  0.000851  0.000282  0.002955  0.000057
# train_loss  0.000584  0.000235  0.002242  0.000029
# ...

# %%
import matplotlib.pyplot as plt
epochs = list(range(1,21))
plt.figure()
plt.title('Training Loss Curve')
plt.plot(epochs,fin[0], label='Lenet5')
plt.plot(epochs,fin[1], label='Resnet18')
plt.plot(epochs,fin[2], label='Alexnet')
plt.plot(epochs,fin[3], label='VGGnet')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\fmnis\metrics_f"
files = os.listdir(path)
fmnist = []
for file in files:
  fmnist.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df_fm = pd.DataFrame(fmnist, index = ['Lenet5', 'Resnet18', 'Alexnet','VGGnet'])
df_fm.transpose()
# Out:
#       Lenet5  Resnet18   Alexnet    VGGnet
# 0   2.288034  0.547878  2.301906  1.209144
# 1   1.766207  0.267781  2.299033  0.693141
# 2   0.941812  0.201167  2.266180  0.567308
# 3   0.777219  0.159008  1.303237  0.494724
# 4   0.689878  0.115267  0.810109  0.442126
# 5   0.637245  0.056935  0.722638  0.398417
# 6   0.630111  0.037223  0.712154  0.391225
# 7   0.623952  0.029407  0.703732  0.385811
# 8   0.618468  0.023876  0.697582  0.380589
# 9   0.612722  0.020327  0.691903  0.376964
# 10  0.608034  0.017124  0.687989  0.372468
# 11  0.607384  0.016784  0.683737  0.371018
# 12  0.606747  0.016380  0.682182  0.370948
# 13  0.606251  0.016186  0.682162  0.369869
# 14  0.605770  0.016017  0.681317  0.369804
# 15  0.605272  0.015776  0.681358  0.369363
# 16  0.605171  0.015809  0.682214  0.369229
# 17  0.605178  0.015435  0.680865  0.368879
# 18  0.605106  0.015845  0.681664  0.369313
# 19  0.605031  0.015700  0.680214  0.369190

# %%
import matplotlib.pyplot as plt
#epochs = list(range(1,21))
plt.figure()
plt.title('Training Loss Curve')
plt.plot(fmnist[0], label='Lenet5')
plt.plot(fmnist[1],label='Resnet18')
plt.plot(fmnist[2], label='Alexnet')
plt.plot(fmnist[3], label='Xceptionnet')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\fmnis\loss_f"
files = os.listdir(path)
fmnist = []
for file in files:
  fmnist.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df1 = pd.DataFrame(fmnist, index= ['Lenet5', 'Resnet18', 'Alexnet','Xceptionnet'])
df1
# Out:
#              Accuracy  Precision    Recall        F1
# Lenet5          76.40   0.800000  0.800000  0.800000
# Resnet18        92.36   0.800000  0.800000  0.800000
# Alexnet         73.85   0.564815  0.592593  0.550794
# Xceptionnet     86.15   0.777778  0.851852  0.792593

# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\mnis\loss_m"
files = os.listdir(path)
mnist = []
for file in files:
  mnist.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df2 = pd.DataFrame(mnist, index= ['Lenet5', 'Resnet18', 'Alexnet','VGGnet'])
df2
# Out:
#           Accuracy  Precision  Recall   F1
# Lenet5       99.11        1.0     1.0  1.0
# Resnet18     99.55        1.0     1.0  1.0
# Alexnet      99.37        1.0     1.0  1.0
# VGGnet       99.42        1.0     1.0  1.0

# %%
import pickle
from pickle import load
import os
import pandas as pd


path = r"C:\Users\USER\Desktop\pickle\loss_c"
files = os.listdir(path)
cifar = []
for file in files:
  cifar.append(pickle.load(open(path + "\\" + file, "rb")))

# %%
df3 = pd.DataFrame(cifar)
df3
# Out:
#    Accuracy  Precision    Recall        F1
# 0     63.92   0.483333  0.444444  0.434127
# 1     80.25   0.700000  0.666667  0.656250
# 2     78.33   0.916667  0.904762  0.893878
# 3     80.34   0.552083  0.583333  0.557143
